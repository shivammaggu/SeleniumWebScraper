# %%
# -> Uncomment and run below commands in Google Colab for this script to work.
#
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# !pip install pandas
# -> Mount Google Drive for retaining scraped data.
#
from google.colab import drive
drive.mount('/content/drive')


# -> Run below command in terminal for this script to work on an Ubuntu system.
# -> Requires python3 and pip3 to be preinstalled on the system.
#
# sudo apt-get install chromium-chromedriver
# pip3 install selenium
# pip3 install pandas


# -> Function def run() is the starting point. Set ENV variable to start scraping.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 59 not upgraded.
# Need to get 75.5 MB of archives.
# After this operation, 256 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 83.0.4103.61-0ubuntu0.18.04.1 [1,119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 83.0.4103.61-0ubuntu0.18.04.1 [66.7 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 83.0.4103.61-0ubuntu0.18.04.1 [3,378 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 83.0.4103.61-0ubuntu0.18.04.1 [4,294 kB]
# Fetched 75.5 MB in 3s (23.5 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 144328 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_83.0.4103.61-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (83.0.4103.61-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_83.0.4103.61-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (83.0.4103.61-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_83.0.4103.61-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (83.0.4103.61-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_83.0.4103.61-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (83.0.4103.61-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (83.0.4103.61-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (83.0.4103.61-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (83.0.4103.61-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (83.0.4103.61-0ubuntu0.18.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 2.8MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from collections import OrderedDict
from selenium import webdriver
import pandas as pd
import time
import os

# %%
# Environemt value needs to be set.
ENV = None
path = None
driver = None
radio_dict_g = None
saved_file_counter = 0
url = ('http://www.wbsec.gov.in/results/panchayat_election_detailed_result?election_year=2013')

# %%
def setup_driver_for_colab():
    global driver
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome('chromedriver', options=options)
    print('Driver setup complete.....')

def setup_driver_for_ubuntu():
    global driver
    PATH_TO_CHROME_DRIVER = '/usr/bin/chromedriver'
    driver = webdriver.Chrome(PATH_TO_CHROME_DRIVER)
    print('Driver setup complete.....')

# %%
def wait():
    time.sleep(6)
    print('Waiting for page and elements to load.....')

# %%
def get_radio_button_options() -> dict:
    global driver
    global radio_dict_g
    if radio_dict_g:
        print('Global radio dictionary = {}'.format(radio_dict_g))
        return radio_dict_g
    radio_dict = OrderedDict()
    i = 0
    radio_selectors = driver.find_elements_by_xpath('//label[@class="form_label"]')
    for radio in radio_selectors:
        radio_dict[i] = {radio.text: radio.find_element_by_tag_name('input').get_attribute('value')}
        i += 1
    radio_dict_g = radio_dict
    print('Radio dictionary = {}'.format(radio_dict))
    return radio_dict

# %%
def select_preferred_radio_button(radio_dict: dict):
    global driver
    value = next(iter(radio_dict[2].values()))
    driver.find_element_by_css_selector('input[type="radio"][value="{}"]'.format(value)).click()
    print('Selecting radio button with name {}'.format(value))
    wait()

# %%
def get_word_from_string(element: str) -> list:
    word_list = []
    word = ''
    for char in element:
        if char == '\n':
            word_list.append(word)
            word = ''
        else:
            word = word + char
    word_list.append(word)
    # print('Word list generated = {}'.format(word_list))
    return word_list

# %%
def get_district_data() -> dict:
    global driver
    district_soup = driver.find_element_by_xpath('//select[@name="zilla_parishad"]')
    district_values = district_soup.find_elements_by_tag_name('option')
    district_dict = OrderedDict()
    for value in district_values:
        val = value.get_attribute('value')
        name = value.text
        if name != '--Select--':
            district_dict[val] = name
    print('District dictionary = {}'.format(district_dict))
    return district_dict

# %%
def select_district(key: str):
    global driver
    driver.find_element_by_xpath('//select[@name="zilla_parishad"]/option[@value="{}"]'.format(key)).click()
    print('Selecting district with key {}'.format(key))
    wait()

# %%
def get_block_data() -> dict:
    global driver
    block_soup = driver.find_element_by_xpath('//select[@name="panchayat_samity"]')
    block_values = block_soup.find_elements_by_tag_name('option')
    block_dict = OrderedDict()
    for value in block_values:
        val = value.get_attribute('value')
        name = value.text
        if name != '--Select--':
            block_dict[val] = name
    print('Block dictionary = {}'.format(block_dict))
    return block_dict

# %%
def select_block(key: str):
    global driver
    driver.find_element_by_xpath('//select[@name="panchayat_samity"]/option[@value="{}"]'.format(key)).click()
    print('Selecting block with key {}'.format(key))
    wait()

# %%
def get_gp_data() -> dict:
    global driver
    gp_soup = driver.find_element_by_xpath('//select[@name="gram_panchayat"]')
    gp_values = gp_soup.find_elements_by_tag_name('option')
    gp_dict = OrderedDict()
    for value in gp_values:
        val = value.get_attribute('value')
        name = value.text
        if name != '--Select--':
            gp_dict[val] = name
    print('GP dictionary = {}'.format(gp_dict))
    return gp_dict

# %%
def select_gp(key: str):
    global driver
    driver.find_element_by_xpath('//select[@name="gram_panchayat"]/option[@value="{}"]'.format(key)).click()
    print('Selecting GP with key {}'.format(key))
    wait()

# %%
def get_polling_data() -> dict:
    global driver
    polling_date_soup = driver.find_element_by_xpath('//select[@name="election_date"]')
    polling_date_values = polling_date_soup.find_elements_by_tag_name('option')
    polling_date_dict = OrderedDict()
    for value in polling_date_values:
        val = value.get_attribute('value')
        name = value.text
        if name != '--Select--':
            polling_date_dict[val] = name
    print('Polling date dictionary = {}'.format(polling_date_dict))
    return polling_date_dict

# %%
def select_polling_date(dt: str):
    global driver
    driver.find_element_by_xpath('//select[@name="election_date"]/option[@value="{}"]'.format(dt)).click()
    print('Selecting date {}'.format(dt))
    wait()

# %%
def submit_form():
    global driver
    driver.find_element_by_xpath('//input[@name="submit"]').click()
    print('Submitting form data.....')
    wait()

# %%
def get_table_data() -> dict:
    global driver
    tables = driver.find_elements_by_xpath('//table[@id="doc_table10"]')
    table_data_dict = {}
    i = 0
    for table in tables:
        table_head_string = ''
        table_head = table.find_element_by_tag_name('thead')
        table_head_rows = table_head.find_element_by_tag_name('tr')
        table_head_data = table_head_rows.find_elements_by_tag_name('th')
        for data in table_head_data:
            table_head_string = table_head_string + '{}\n'.format(data.text)
        table_body = table.find_element_by_tag_name('tbody')
        table_rows = table_body.find_elements_by_tag_name('tr')
        table_head_list = get_word_from_string(element=table_head_string[:-1])
        temp_row_list = []
        temp_row_list.append(table_head_list)
        for table_row in table_rows:
            table_datas = table_row.find_elements_by_tag_name('td')
            temp_data_list = []
            for table_data in table_datas:
                if table_data.text:
                    temp_data_list.append(table_data.text)
                else:
                    temp_data_list.append('-')
            temp_row_list.append(temp_data_list)
        table_data_dict[i] = temp_row_list
        i += 1
    print('Fetched data from table = {}'.format(table_data_dict))
    return table_data_dict

# %%
def save_page_to_dataframe(from_dict: dict):
    main_df = pd.DataFrame()
    for key in from_dict:
        values = from_dict[key]
        column = values[0]
        df = pd.DataFrame(values[1:], columns=column)
        df['Seat Name'] = df['Seat Name'].str.replace('\n', ' ')
        print('Formatting Seat Name column for garbage data.....')
        main_df = pd.concat([main_df, df], ignore_index=True)
        print('Concatenating dataframes.....')
    print('Returning main dataframe.....')
    return main_df

# %%
def save_to_csv(dataframe, filename: str) -> bool:
    global saved_file_counter
    global path
    saved_file_counter += 1
    if not os.path.isdir(path):
        os.mkdir(path)
        print('Creating a new directory at path {}.....'.format(path))
    complete_filename = '{}. {}'.format(saved_file_counter, filename)
    dataframe.to_csv(os.path.join(path, complete_filename), index=False, encoding='utf-8')
    print('Saving file with name {} to path {}'.format(complete_filename, path))
    if dataframe.empty:
        print('Found empty dataframe.....')
        print('Restarting from point of failure.....')
        return False
    else:
        return True

# %%
def run():
    setup_driver_for_env()
    global driver
    data = tuple()
    driver.get(url)
    wait()
    # print(driver.page_source)
    setup_path()
    select_preferred_radio_button(radio_dict=get_radio_button_options())
    district_dict = get_district_data()
    for key1 in district_dict:
        name1 = district_dict[key1]
        select_district(key=key1)
        block_dict = get_block_data()
        for key2 in block_dict:
            name2 = block_dict[key2]
            select_block(key=key2)
            gp_dict = get_gp_data()
            for key3 in gp_dict:
                name3 = gp_dict[key3]
                select_gp(key=key3)
                polling_date_dict = get_polling_data()
                for key4 in polling_date_dict:
                    dt = polling_date_dict[key4]
                    select_polling_date(dt=key4)
                    submit_form()
                    table_data_dict = get_table_data()
                    df = save_page_to_dataframe(from_dict=table_data_dict)
                    data = (key1, key2, key3)
                    print('Checkpoint values {}'.format(data))
                    status = save_to_csv(dataframe=df, 
                                         filename='{}_{}_{}_{}.csv'.format(name1, name2, name3, dt))
                    if status == False:
                        return restart_from_fail_point(data=data, check=True)
    print('Ending scraping.....')

# %%
def restart_from_fail_point(data: tuple, check: bool):
    setup_driver_for_env()
    if check:
        (a, b, c) = data
    global driver
    driver.get(url)
    wait()
    # print(driver.page_source)
    setup_path()
    select_preferred_radio_button(radio_dict=get_radio_button_options())
    district_dict = get_district_data()
    if check:
        district_dict = remove_from(dict_value=district_dict, till=a, gp=False)
    for key1 in district_dict:
        name1 = district_dict[key1]
        select_district(key=key1)
        block_dict = get_block_data()
        if check:
            block_dict = remove_from(dict_value=block_dict, till=b, gp=False)
        for key2 in block_dict:
            name2 = block_dict[key2]
            select_block(key=key2)
            gp_dict = get_gp_data()
            if check:
                gp_dict = remove_from(dict_value=gp_dict, till=c, gp=True)
                if not gp_dict:
                    check = False
                    continue
            for key3 in gp_dict:
                name3 = gp_dict[key3]
                select_gp(key=key3)
                polling_date_dict = get_polling_data()
                for key4 in polling_date_dict:
                    dt = polling_date_dict[key4]
                    select_polling_date(dt=key4)
                    submit_form()
                    table_data_dict = get_table_data()
                    df = save_page_to_dataframe(from_dict=table_data_dict)
                    datas = (key1, key2, key3)
                    print('Checkpoint values {}'.format(datas))
                    status = save_to_csv(dataframe=df, 
                                         filename='{}_{}_{}_{}.csv'.format(name1, name2, name3, dt))
                    if status == False:
                        return restart_from_fail_point(data=datas, check=True)
                    else: 
                        check = False
    print('Ending scraping.....')

# %%
def remove_from(dict_value: dict, till: str, gp: bool = False) -> dict:
    temp = dict_value.copy()
    for key in temp:
        if key == till:
            if gp == True:
                dict_value.pop(key, '')
            print('LEFT OVER DATA AFTER REMOVING {}'.format(dict_value))
            return dict_value
        else:
            dict_value.pop(key, '')

# %%
def setup_driver_for_env():
    global ENV
    if ENV == 'colab':
        # Driver setup for Google Colab.
        setup_driver_for_colab()
        print('Setting environment for {}'.format(ENV))
    elif ENV == 'ubuntu':
        # Driver setup for Ubuntu system.
        setup_driver_for_ubuntu()
        print('Setting environment for {}'.format(ENV))
    else:
        print('Please set the ENV variable to a valid environment. Allowed values are colab and ubuntu')
        print('Please provide a valid ENV value')
        return

# %%
def setup_path():
    global path
    global ENV
    if ENV == 'colab':
        # Path variable for Googlo Colab.
        dir_name = next(iter(get_radio_button_options()[2].keys()))
        path = os.path.join(os.getcwd(), 'drive/My Drive', dir_name)
    if ENV == 'ubuntu':
        # Path variable for Ubuntu System.
        dir_name = next(iter(get_radio_button_options()[2].keys()))
        path = os.path.join(os.getcwd(), dir_name)
    print('Selecting path {} for environment {}'.format(path, ENV))

# %%
# Execute this block when running the script for the very first time.
# To resume an existing progress, use the block of code in the cell below.
# ENV variable should be set to a valid option. Possible values are: 'colab', 'ubuntu'.
# 
global ENV
ENV = 'colab'

run()

# %%
# Execute this block only in the case of a runtime deallocation or to start scraping from a checkpoint value.
# To execute this block, values for data tuple will be in the format of ('0', '0', '0').
# To resume progress, take the last checkpoint values from the log and put in the data tuple.
# Also change the global saved_file_counter to the value of last file number saved (Check file number from files saved to Google Drive)
# ENV variable should be set to a valid option. Possible values are: 'colab', 'ubuntu'.
#
# global ENV
# ENV = 'colab'
# 
# global saved_file_counter
# saved_file_counter = 0
# 
# data = ('0', '0', '0')
# 
# restart_from_fail_point(data=data, check=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1240')
# Saving file with name 2916. South 24-Parganas_SONARPUR_BANGOOGHLY-I_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1241
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '767', '606', '39', '1', 'CHAMPA NASKAR', 'CPIM', '261'], ['-', '-', '-', '-', '2', 'PARBATI NASKAR', 'AITC', '279'], ['-', '-', '-', '-', '3', 'RUMPA MANDAL', 'INC', '27']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nW', '694', '577', '17', '1', 'BULA NAIYA', 'IND', '5'], ['-', '-', '-', '-', '2', 'SAFURA FAKIR', 'IND', '319'], ['-', '-', '-', '-', '3', 'SAHANAJ BIBI FAKIR', 'AITC', '236']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nGeneral', '726', '640', '25', '1', 'ARIF MISTRY', 'IND', '402'], ['-', '-', '-', '-', '2', 'BANESH NARU', 'IND', '4'], ['-', '-', '-', '-', '3', 'HASEM LASKAR', 'AITC', '209']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nSC', '945', '798', '19', '1', 'TARUN BAG', 'CPIM', '314'], ['-', '-', '-', '-', '2', 'TAPAS NARU', 'INC', '194'], ['-', '-', '-', '-', '3', 'PRATAP BAG', 'AITC', '271']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nSCW', '1099', '959', '47', '1', 'AJANTA KHELUYA', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SONALI MAJHI', 'IND', '-']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '791', '672', '17', '1', 'APARNA MANDAL', 'CPIM', '339'], ['-', '-', '-', '-', '2', 'AZMIRA GAZI', 'AITC', '252'], ['-', '-', '-', '-', '3', 'JARINA MONDAL', 'INC', '47'], ['-', '-', '-', '-', '4', 'RAHENA BIBI MANDAL', 'SUCI', '17']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nGeneral', '796', '608', '31', '1', 'KAZI MAHARUL MEHER', 'AIUDF', '-'], ['-', '-', '-', '-', '2', 'GOLAM SEKH', 'SUCI', '-'], ['-', '-', '-', '-', '3', 'MASUD MIR', 'CPIM', '-'], ['-', '-', '-', '-', '4', 'SAFIR UDDIN JAMADAR', 'INC', '-'], ['-', '-', '-', '-', '5', 'HASHEM ALI MOLLAH', 'AITC', '-']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nW', '729', '576', '6', '1', 'OHIDA SEKH', 'SUCI', '15'], ['-', '-', '-', '-', '2', 'ROKEYA KHATUN ( LASKAR )', 'CPIM', '340'], ['-', '-', '-', '-', '3', 'SALEHA MOLLA', 'INC', '12'], ['-', '-', '-', '-', '4', 'SALAHA LASKAR', 'AITC', '203']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nGeneral', '1008', '867', '25', '1', 'KURBAN ALI LASKAR', 'INC', '-'], ['-', '-', '-', '-', '2', 'MD. SAHAJAN ALI GAZI', 'AITC', '-'], ['-', '-', '-', '-', '3', 'SAHAJAHAN MOLLA', 'CPIM', '-']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nSC', '1286', '1128', '51', '1', 'KISHORI NARU', 'INC', '-'], ['-', '-', '-', '-', '2', 'DIBYENDU BARUI', 'CPIM', '-'], ['-', '-', '-', '-', '3', 'PRAVASH CHANDRA KHELUYA', 'AITC', '-']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nGeneral', '709', '633', '13', '1', 'ABDUL SAHID MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SACHIN GHOSH', 'CPIM', '-'], ['-', '-', '-', '-', '3', 'SUJIT GHOSH', 'IND', '-']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nBCW', '709', '617', '12', '1', 'ANOWARA MONDAL', 'AITC', '233'], ['-', '-', '-', '-', '2', 'MONJILA MONDAL', 'INC', '210'], ['-', '-', '-', '-', '3', 'SAMMA BIBI MANDAL', 'CPIM', '162']], 12: [ ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1241')
# Saving file with name 2917. South 24-Parganas_SONARPUR_BANHOOGHLY-II_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1242
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '1153', '955', '33', '1', 'RAMA MONDAL', 'AITC', '432'], ['-', '-', '-', '-', '2', 'SARBANI MONDAL', 'CPIM', '490']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSC', '904', '771', '21', '1', 'DILIP KUMAR MONDAL', 'INC', '6'], ['-', '-', '-', '-', '2', 'NABIN NASKAR', 'AITC', '320'], ['-', '-', '-', '-', '3', 'PROBIR HALDER', 'IND', '3'], ['-', '-', '-', '-', '4', 'SUKHEN MONDAL', 'CPIM', '421']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nSCW', '1160', '949', '43', '1', 'KANA NASKAR', 'CPIM', '453'], ['-', '-', '-', '-', '2', 'RUMPA MONDAL', 'AITC', '453']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nSC', '785', '696', '16', '1', 'DILIP MONDAL', 'INC', '26'], ['-', '-', '-', '-', '2', 'MADHAB MONDAL', 'AITC', '375'], ['-', '-', '-', '-', '3', 'SUSANTA SARDAR', 'CPIM', '279']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nW', '549', '485', '20', '1', 'RASIDA KHATUN', 'INC', '16'], ['-', '-', '-', '-', '2', 'RINA MONDAL', 'AITC', '209'], ['-', '-', '-', '-', '3', 'REHANA GAZI', 'CPIM', '240']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '681', '622', '25', '1', 'MAMTAJ SARDAR', 'AITC', '314'], ['-', '-', '-', '-', '2', 'SAJIDA BIBI', 'CPIM', '283']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nGeneral', '1008', '845', '45', '1', 'RUMPA NASKAR', 'AITC', '335'], ['-', '-', '-', '-', '2', 'SHANKAR KR. NASKAR', 'CPIM', '232'], ['-', '-', '-', '-', '3', 'SHYAMAL MONDAL', 'IND', '233']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nW', '1045', '825', '16', '1', 'SAINAJ KHATUN BEGAM', 'AITC', '416'], ['-', '-', '-', '-', '2', 'SUFIYA BIBI', 'CPIM', '310'], ['-', '-', '-', '-', '3', 'SERINA', 'INC', '83']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nGeneral', '760', '629', '47', '1', 'ATABUDDIN SARDAR', 'IND', '3'], ['-', '-', '-', '-', '2', 'OSMAN SARDAR', 'INC', '141'], ['-', '-', '-', '-', '3', 'MUNSI JAMAL UDDIN', 'AITC', '209'], ['-', '-', '-', '-', '4', 'RAFIK MOLLA', 'CPIM', '229']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nSCW', '823', '664', '26', '1', 'PUSPANJALI GAYEN', 'AITC', '-'], ['-', '-', '-', '-', '2', 'RUMPA MONDAL', 'INC', '-'], ['-', '-', '-', '-', '3', 'SUMITRA NASKAR', 'CPIM', '-']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nSC', '810', '671', '34', '1', 'JAYANTA DAS', 'AITC', '258'], ['-', '-', '-', '-', '2', 'SUJAN DAS', 'CPIM', '379']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nGeneral', '1116', '916', '70', '1', 'KAMALESH CHAKRABORTY', 'CPIM', '563'], ['-', '-', '-', '-', '2', 'PARIMAL BHATTACHARYA', 'AITC', '283']]}
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1242')
# Saving file with name 2918. South 24-Parganas_SONARPUR_KALIKAPUR-I_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1243
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nW', '813', '621', '51', '1', 'JYOTSNA GHOSH', 'CPIM', '340'], ['-', '-', '-', '-', '2', 'PARAMITA GHOSH', 'AITC', '230']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSCW', '1038', '820', '2', '1', 'BANDANA MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'RUMA HALDER', 'AITC', '-']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nW', '828', '688', '3', '1', 'ROKEA BAIDYA', 'CPIM', '240'], ['-', '-', '-', '-', '2', 'LICIA MONDAL', 'AITC', '420'], ['-', '-', '-', '-', '3', 'SHUKLA DAS', 'INC', '25']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nW', '788', '690', '64', '1', 'SAKINA BIBI', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SAJIDA BEGAM', 'AITC', '-']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nW', '1074', '833', '18', '1', 'SHARMILA MONDAL', 'AITC', '278'], ['-', '-', '-', '-', '2', 'SANTANA NASKAR', 'CPIM', '537']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nGeneral', '947', '764', '22', '1', 'AJOY PAL', 'AITC', '248'], ['-', '-', '-', '-', '2', 'BAPI MONDAL', 'SUCI', '154'], ['-', '-', '-', '-', '3', 'SRIDAM CHANDRA PAL', 'CPIM', '340']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSC', '890', '727', '17', '1', 'DIPANKAR MONDAL', 'CPIM', '288'], ['-', '-', '-', '-', '2', 'BIKASH BISWAS', 'IND', '40'], ['-', '-', '-', '-', '3', 'SUBHASHISH NASKAR', 'INC', '53'], ['-', '-', '-', '-', '4', 'HARAN CHANDRA BISWAS', 'AITC', '329']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nSCW', '947', '755', '42', '1', 'REKHA SANFUI', 'AITC', '357'], ['-', '-', '-', '-', '2', 'SOVA SANFUI', 'CPIM', '356']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nSC', '937', '729', '26', '1', 'TAGAR BALA MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SWARAJ NASKAR', 'CPIM', '-']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '1338', '1075', '72', '1', 'BINAPANI MONDAL', 'AITC', '518'], ['-', '-', '-', '-', '2', 'MITHU MONDAL', 'CPIM', '485']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nSC', '691', '603', '12', '1', 'DINABANDHU NASKAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'BIJU MISTRY', 'CPI', '-'], ['-', '-', '-', '-', '3', 'SHAILENDRA NATH MONDAL', 'INC', '-']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nSC', '788', '700', '40', '1', 'KARTICK MONDAL', 'CPIM', '452'], ['-', '-', '-', '-', '2', 'TAPAN BISWAS', 'AITC', '208']], 12: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIII/13\nGeneral', '571', '494', '60', '1', 'AMAL NASKAR', 'CPIM', '287'], ['-', '-', '-', '-', '2', 'NEMAI CHANDRA MONDAL', 'AITC', '147']], 13: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIV/14\nGeneral', '761', '689', '55', '1', 'KANOJ MONDAL', 'AITC', '271'], ['-', '-', '-', '-', '2', 'GOURPADA MONDAL', 'INC', '4'], ['-', '-', '-', '-', '3', 'MONOJIT BISWAS', 'IND', '5'], ['-', '-', '-' ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1243')
# Saving file with name 2919. South 24-Parganas_SONARPUR_KALIKAPUR-II_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1244
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '974', '868', '8', '1', 'MAYA MONDAL', 'CPIM', '391'], ['-', '-', '-', '-', '2', 'SUKLA SARDAR', 'AITC', '469']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nW', '628', '551', '14', '1', 'NAYAN DAS', 'AITC', '259'], ['-', '-', '-', '-', '2', 'SARALA MONDAL', 'CPIM', '278']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nSC', '977', '828', '23', '1', 'DEBABRATA KAYAL', 'IND', '83'], ['-', '-', '-', '-', '2', 'NIRANJAN NASKAR', 'CPIM', '353'], ['-', '-', '-', '-', '3', 'PANCHU MONDAL', 'AITC', '369']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nGeneral', '651', '573', '6', '1', 'SOMNATH MONDAL', 'CPI', '306'], ['-', '-', '-', '-', '2', 'HARICHARAN MONDAL', 'AITC', '261']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nSCW', '714', '588', '30', '1', 'PAMPA MONDAL', 'CPIM', '249'], ['-', '-', '-', '-', '2', 'REKHA MONDAL', 'AITC', '309']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nSC', '1024', '848', '71', '1', 'JHARNA MONDAL', 'AITC', '322'], ['-', '-', '-', '-', '2', 'MINU NASKAR', 'IND', '349'], ['-', '-', '-', '-', '3', 'RINA MANDAL', 'RSP', '106']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nW', '771', '635', '88', '1', 'MITALI DAS', 'IND', '178'], ['-', '-', '-', '-', '2', 'SARATHI DAS', 'CPIM', '110'], ['-', '-', '-', '-', '3', 'HEMLATA GAYEN', 'AITC', '259']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nGeneral', '1484', '1196', '52', '1', 'AHINDRA NATH MONDAL', 'AITC', '651'], ['-', '-', '-', '-', '2', 'PRASANTA DAS', 'BJP', '53'], ['-', '-', '-', '-', '3', 'MALAY KUMAR MONDAL', 'CPIM', '440']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nSC', '873', '695', '52', '1', 'ALOKE MONDAL (FATHER LATE AJIT KUMAR MONDAL)', 'IND', '101'], ['-', '-', '-', '-', '2', 'ALOKE MONDAL (FATHER LATE ATUL MONDAL)', 'CPIM', '202'], ['-', '-', '-', '-', '3', 'PANNALAL NASKAR', 'BJP', '26'], ['-', '-', '-', '-', '4', 'RABIN CHANDRA DAS', 'AITC', '314']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '942', '817', '14', '1', 'NILIMA MONDAL', 'AITC', '517'], ['-', '-', '-', '-', '2', 'BANDANA MONDAL', 'CPIM', '286']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nSC', '629', '536', '10', '1', 'GOUTAM MONDAL', 'IND', '146'], ['-', '-', '-', '-', '2', 'JAHAR MONDAL', 'CPIM', '123'], ['-', '-', '-', '-', '3', 'BAPPA MONDAL', 'AITC', '257']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nSC', '858', '741', '20', '1', 'MONOJ BAIDYA', 'CPI', '331'], ['-', '-', '-', '-', '2', 'MADHAI MONDAL', 'AITC', '390']], 12: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIII/13\nGeneral', '1142', '931', '15', '1', 'APU MONDAL', 'AITC', '526'], ['-', '-', '-', '-', '2', 'CHANDRA NATH MONDAL', 'CPIM', '390']], 13: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIV/14\nW', '1099', '869', ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1244')
# Saving file with name 2920. South 24-Parganas_SONARPUR_KAMRABAD_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1245
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nW', '985', '-', '-', '1', 'KALYANI MONDAL', 'AITC', '-']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSCW', '1425', '477', '38', '1', 'ANJANA MONDAL', 'CPIM', '275'], ['-', '-', '-', '-', '2', 'LATIKA BAR', 'AITC', '164']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nW', '1095', '853', '41', '1', 'KRISHNA GHOSHAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'DIPALI SANFUI', 'CPIM', '-']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nW', '794', '649', '19', '1', 'MOUMITA NASKAR', 'CPIM', '280'], ['-', '-', '-', '-', '2', 'SANDHYA NASKAR', 'AITC', '350']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nGeneral', '822', '651', '25', '1', 'SHANTI PYKE', 'CPIM', '447'], ['-', '-', '-', '-', '2', 'SUKUMAR MONDAL', 'AITC', '179']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nST', '626', '548', '19', '1', 'BIKASH MUNDA', 'CPIM', '312'], ['-', '-', '-', '-', '2', 'RANJIT URANG', 'AITC', '217']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nGeneral', '849', '752', '17', '1', 'RAMPADA GAYEN', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SHAMBHU NATH CHAKRABORTY', 'AITC', '-']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nSCW', '1127', '910', '27', '1', 'BRIHASPATI MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'MADHUMITA HALDER', 'AITC', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nW', '934', '682', '20', '1', 'REKHA MANDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SARASWATI SARDAR', 'CPIM', '-']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nSC', '731', '572', '8', '1', 'GOURI SHANKAR MONDAL', 'CPIM', '167'], ['-', '-', '-', '-', '2', 'SANJOY MONDAL', 'AITC', '397']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nSCW', '465', '333', '9', '1', 'ARATI MONDAL', 'CPIM', '93'], ['-', '-', '-', '-', '2', 'BHANUMATI GHARUI', 'AITC', '231']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nSC', '1004', '886', '15', '1', 'DEBPROSAD MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'BISWAJIT MONDAL', 'CPIM', '-']], 12: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIII/13\nSC', '1200', '1061', '31', '1', 'GORA CHAND NASKAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'BAPI SARDAR', 'IND', '-'], ['-', '-', '-', '-', '3', 'SANJAY KUMAR NASKAR', 'CPIM', '-']], 13: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIV/14\nGeneral', '672', '636', '8', '1', 'DIPANKAR MONDAL', 'CPIM', '229'], ['-', '-', '-', '-', '2', 'SAHADEV NASKAR', 'AITC', '399']]}
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1245')
# Saving file with name 2921. South 24-Parganas_SONARPUR_KHEYADAHA-I_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1246
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '996', '-', '-', '1', 'PAPIYA NASKAR', 'AITC', '-']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nW', '1179', '947', '103', '1', 'ANANDAMAYEE GAYEN', 'CPIM', '470'], ['-', '-', '-', '-', '2', 'JHUMUR BAR', 'AITC', '374']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nSC', '1139', '920', '30', '1', 'ABHIJIT MAKAL', 'AITC', '522'], ['-', '-', '-', '-', '2', 'SUSHANTA BAG', 'CPIM', '368']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nGeneral', '932', '762', '21', '1', 'GOPAL MIDDE', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SWAPAN BAR', 'AITC', '-']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nSC', '1256', '493', '18', '1', 'NARAYAN BISWAS', 'CPIM', '217'], ['-', '-', '-', '-', '2', 'PRASHANTA BISWAS', 'AITC', '232'], ['-', '-', '-', '-', '3', 'PRITAM NASKAR', 'BJP', '26']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '1190', '860', '27', '1', 'JHARNA PAUL', 'CPIM', '303'], ['-', '-', '-', '-', '2', 'SHANTI ROYCHOWDHURY', 'AITC', '530']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nGeneral', '1110', '868', '28', '1', 'ANANDA PRAMANIK', 'AITC', '543'], ['-', '-', '-', '-', '2', 'BHUTNATH BAG', 'CPIM', '274'], ['-', '-', '-', '-', '3', 'SUDHIR DAS', 'BJP', '23']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nSCW', '744', '553', '52', '1', 'ASIMA SARDAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'IRA SARDAR', 'CPIM', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nW', '725', '573', '16', '1', 'CHANDANA MANDAL', 'AITC', '262'], ['-', '-', '-', '-', '2', 'MALATI SARKAR', 'BJP', '33'], ['-', '-', '-', '-', '3', 'SHILPI KAYAL', 'CPIM', '262']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nGeneral', '752', '612', '14', '1', 'NARAN MONDAL', 'CPIM', '366'], ['-', '-', '-', '-', '2', 'BAPI BAR', 'AITC', '232']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nW', '1190', '944', '25', '1', 'TILAKA MONDAL', 'CPIM', '431'], ['-', '-', '-', '-', '2', 'RITA MONDAL', 'AITC', '488']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nSCW', '972', '765', '37', '1', 'MANDIRA MONDAL', 'CPIM', '334'], ['-', '-', '-', '-', '2', 'MITA NASKAR', 'AITC', '394']], 12: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIII/13\nSC', '515', '433', '9', '1', 'DINESH MONDAL', 'CPIM', '146'], ['-', '-', '-', '-', '2', 'SASANKA MONDAL', 'AITC', '278']], 13: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIV/14\nGeneral', '1109', '875', '24', '1', 'TAPAN SAU', 'CPIM', '241'], ['-', '-', '-', '-', '2', 'PRABIR SARKAR', 'AITC', '610']], 14: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XV/15\nSCW', '987', '726', '7', '1', 'BHABANI MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SANCHITA HAOLADAR', 'AITC', '-']], 15: [ ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1246')
# Saving file with name 2922. South 24-Parganas_SONARPUR_KHEYADAHA-II_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1247
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nW', '1337', '-', '-', '1', 'ARATI DAS', 'INC', '-'], ['-', '-', '-', '-', '2', 'PURNIMA MANDAL', 'AITC', '-'], ['-', '-', '-', '-', '3', 'SANTI MAJHI', 'CPIM', '-']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSCW', '855', '-', '-', '1', 'ILA SARDAR', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'USHA GAYAN', 'INC', '-'], ['-', '-', '-', '-', '3', 'SUSOMA MONDAL', 'AITC', '-']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nSCW', '854', '-', '-', '1', 'TAPESH BHATTACHARYYA', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'DILIP NAG', 'INC', '-'], ['-', '-', '-', '-', '3', 'PRAMOD KANTA HAZARI', 'IND', '-'], ['-', '-', '-', '-', '4', 'BHAJAN SARDAR', 'BJP', '-'], ['-', '-', '-', '-', '5', 'SARSWATI PAL', 'AITC', '-']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nSC', '644', '-', '-', '1', 'KARTICK SARDAR', 'INC', '-'], ['-', '-', '-', '-', '2', 'JAYDEB NASKAR', 'IND', '-'], ['-', '-', '-', '-', '3', 'BAPI MONDAL', 'BJP', '-'], ['-', '-', '-', '-', '4', 'MOHAN NASKAR', 'CPIM', '-'], ['-', '-', '-', '-', '5', 'SUNITA MONDAL', 'AITC', '-']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nGeneral', '1139', '-', '-', '1', 'ACHIN CHATTERJEE', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'BISWAJIT CHATTERJEE (BHOLA)', 'IND', '-'], ['-', '-', '-', '-', '3', 'BISWANATH DAS', 'AITC', '-'], ['-', '-', '-', '-', '4', 'SUBRATA ROY', 'INC', '-']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '714', '-', '-', '1', 'INDRANI GHOSH', 'INC', '-'], ['-', '-', '-', '-', '2', 'JAHANARA BIBI MISTRY', 'AITC', '-'], ['-', '-', '-', '-', '3', 'SAHANA MISTRY', 'CPI', '-']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSCW', '737', '-', '-', '1', 'RINA NASKAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'RUPALI MONDAL', 'BJP', '-'], ['-', '-', '-', '-', '3', 'SAMPA MONDAL', 'CPIM', '-']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nSC', '893', '-', '-', '1', 'ADHIR CHANDRA PRAMANIK', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'BIMAN MONDAL', 'AITC', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nSCW', '1124', '-', '-', '1', 'JAYA PRAMANIK', 'AITC', '-'], ['-', '-', '-', '-', '2', 'MANGALA MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '3', 'SULEKHA BANSHI', 'BJP', '-']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '633', '-', '-', '1', 'ALO CHATTERJEE', 'INC', '-'], ['-', '-', '-', '-', '2', 'JYOTSNA SARKAR', 'CPIM', '-'], ['-', '-', '-', '-', '3', 'MIRA DAS', 'AITC', '-']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nBC', '860', '-', '-', '1', 'DULAL GHOSH', 'INC', '-'], ['-', '-', '-', '-', '2', 'PRADIP GHOSH', 'CPIM', '-'], ['-', '-', '-', '-', '3', 'RAM CHANDRA GHOSH', 'AITC', '-']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nGeneral', '739', '-', '-', '1', 'JYOTIRMOY GHOSH', 'IND', '-'], ['-', '-', '-', '-', '2', 'BASUDEB CHAKRABORTY', 'AITC', '-'], ['-', '-', '-', '-', '3', 'SANJAY BHATTACHARYA', 'CPIM', '-'], ['-', '-', '-', '-', '4', 'SUSHANT ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1247')
# Saving file with name 2923. South 24-Parganas_SONARPUR_LANGALBERIA_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1248
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nW', '908', '858', '6', '1', 'APARNA PRAMANIK', 'CPIM', '406'], ['-', '-', '-', '-', '2', 'APARNA MONDAL', 'AITC', '446']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSCW', '1105', '-', '-', '1', 'ARATI PANJA', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SHILA BAR', 'AITC', '-']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nGeneral', '838', '761', '20', '1', 'MUJIT ALI GAZI', 'CPIM', '341'], ['-', '-', '-', '-', '2', 'SWAPAN NASKAR', 'AITC', '400']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nBC', '900', '805', '14', '1', 'ENSAN MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'JOHN KUMAR NARU', 'CPIM', '-']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nBC', '1144', '986', '21', '1', 'NOOR ISLAM MOLLA', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SELIM SEKH', 'AITC', '-']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '656', '577', '21', '1', 'KAZI MEHEBUBA', 'AITC', '178'], ['-', '-', '-', '-', '2', 'SALMA KAZI', 'INC', '47'], ['-', '-', '-', '-', '3', 'SAHIDA SEKH', 'CPIM', '331']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSCW', '860', '755', '13', '1', 'ANJANA MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'TUSI SARDAR', 'CPIM', '-']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nGeneral', '742', '598', '19', '1', 'TUKTUKI GHOSH', 'IND', '-'], ['-', '-', '-', '-', '2', 'BIDYUT GHOSH', 'CPIM', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nGeneral', '781', '652', '19', '1', 'AKHAND ANOWARARUL HOQUE', 'AITC', '-'], ['-', '-', '-', '-', '2', 'TAJ MAHAMMAD MONDAL', 'IND', '-']]}
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('16', '310', '1248')
# Saving file with name 2924. South 24-Parganas_SONARPUR_POLEGHAT_19-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1249
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-19', '19-07-2013')])
# Selecting date 2013-07-19
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '827', '703', '37', '1', 'MADHABI NASKAR', 'CPIM', '168'], ['-', '-', '-', '-', '2', 'SUKRITI PRAMANIK', 'AITC', '498']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSC', '537', '499', '43', '1', 'KARTIK SARDAR', 'CPIM', '183'], ['-', '-', '-', '-', '2', 'BHAJAN NASKAR', 'AITC', '273']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nSCW', '806', '680', '22', '1', 'TAPASI MONDAL', 'AITC', '-'], ['-', '-', '-', '-', '2', 'RINKU MONDAL', 'CPIM', '-']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nW', '761', '646', '12', '1', 'TUMPA PAL', 'AITC', '366'], ['-', '-', '-', '-', '2', 'RAMA PAUL', 'CPIM', '268']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nGeneral', '809', '698', '13', '1', 'BOMKESH NASKAR', 'AITC', '354'], ['-', '-', '-', '-', '2', 'MALEK ALI FAKIR', 'CPIM', '331']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nW', '1093', '898', '26', '1', 'RATNA MONDAL', 'AITC', '506'], ['-', '-', '-', '-', '2', 'SHOBHA NASKAR', 'CPIM', '366']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSC', '835', '743', '25', '1', 'NETAI CH. SARDAR', 'AITC', '348'], ['-', '-', '-', '-', '2', 'SANJIB SARDAR', 'CPIM', '201'], ['-', '-', '-', '-', '3', 'SAMIR NASKAR', 'IND', '169']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nW', '799', '650', '40', '1', 'TANDRA SARDAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'MOUSUMI ROY', 'IND', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nSCW', '950', '817', '19', '1', 'PAPIYA SARDAR', 'CPI', '-'], ['-', '-', '-', '-', '2', 'SUPROVA SARDAR', 'AITC', '-']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '605', '508', '7', '1', 'KALYANI MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'MUNMUN SARKAR', 'AITC', '-']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XI/11\nGeneral', '953', '778', '11', '1', 'MOUSTHOFA ALI MOLLAH', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'SUNNAT MOLLA', 'AITC', '-']], 11: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XII/12\nGeneral', '1165', '512', '7', '1', 'DEBNATH DUTTA', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SHUBHANKAR HALDAR', 'CPIM', '-']], 12: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIII/13\nSC', '1185', '341', '3', '1', 'JOYDEB MONDAL', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'TARUN KUMAR SANFUI', 'AITC', '-']], 13: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['XIV/14\nSC', '1208', '1052', '22', '1', 'BHUPAL SARDAR', 'AITC', '-'], ['-', '-', '-', '-', '2', 'SANJAY SARDAR', 'CPIM', '-']]}
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('18', '338', '1735')
# Saving file with name 3026. Uttar Dinajpur_RAIGANJ_RAMPUR_25-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1736
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-25', '25-07-2013')])
# Selecting date 2013-07-25
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '1030', '924', '10', '1', 'ASHALATA BARMAN', 'CPIM', '438'], ['-', '-', '-', '-', '2', 'GAYA BARMAN', 'SP(WB)', '19'], ['-', '-', '-', '-', '3', 'THANDA BARMAN', 'AITC', '33'], ['-', '-', '-', '-', '4', 'MADHUMALA BARMAN', 'INC', '424']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSC', '1103', '983', '32', '1', 'JOYHARI BARMAN', 'SP(WB)', '158'], ['-', '-', '-', '-', '2', 'DAYAL BARMAN', 'AITC', '132'], ['-', '-', '-', '-', '3', 'DIPALI BARMAN', 'BJP', '355'], ['-', '-', '-', '-', '4', 'DIJENDRA NATH BARMAN', 'RSP', '140'], ['-', '-', '-', '-', '5', 'NARAYAN CHANDRA BARMAN', 'INC', '166']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nW', '636', '578', '45', '1', 'SHILPI BISWAS HALDER', 'CPIM', '93'], ['-', '-', '-', '-', '2', 'SHEFALI BARMAN', 'SP(WB)', '88'], ['-', '-', '-', '-', '3', 'SUNATI MURMU', 'INC', '198'], ['-', '-', '-', '-', '4', 'SEMLA BARMAN', 'AITC', '154']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nW', '587', '517', '21', '1', 'GITA BALA (BARMAN) ROY', 'AITC', '123'], ['-', '-', '-', '-', '2', 'CHUMKI TUDU', 'SP(WB)', '40'], ['-', '-', '-', '-', '3', 'RANI MARDI', 'CPIM', '135'], ['-', '-', '-', '-', '4', 'SAMPA BARMAN', 'INC', '198']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nSCW', '915', '798', '17', '1', 'KHADAR BARMAN', 'SP(WB)', '97'], ['-', '-', '-', '-', '2', 'TALOKI BARMAN', 'AITC', '51'], ['-', '-', '-', '-', '3', 'PUSPA BARMAN (ROY)', 'INC', '345'], ['-', '-', '-', '-', '4', 'PURNIMA BARMAN', 'CPIM', '288']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nSCW', '538', '487', '10', '1', 'KAJAL BARMAN', 'CPIM', '196'], ['-', '-', '-', '-', '2', 'PUTUL BARMAN', 'INC', '114'], ['-', '-', '-', '-', '3', 'MATO BARMAN', 'AITC', '52'], ['-', '-', '-', '-', '4', 'SANTANA ROY', 'SP(WB)', '115']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSC', '1060', '968', '18', '1', 'PULIN CHANDRA BARMAN', 'CPIM', '477'], ['-', '-', '-', '-', '2', 'MAHEN BARMAN', 'AITC', '154'], ['-', '-', '-', '-', '3', 'HARI MOHAN SARKAR', 'INC', '302'], ['-', '-', '-', '-', '4', 'HIRENDRA NATH DEBSARMA', 'SP(WB)', '17']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nW', '889', '823', '10', '1', 'CHAMPABATI CHOUHAN', 'IND', '177'], ['-', '-', '-', '-', '2', 'TILAKTAMA BARMAN', 'INC', '266'], ['-', '-', '-', '-', '3', 'PUTUL BARMAN', 'RSP', '27'], ['-', '-', '-', '-', '4', 'MINA ROY', 'AITC', '112'], ['-', '-', '-', '-', '5', 'SHIBANI BHOWMICK', 'BJP', '137'], ['-', '-', '-', '-', '6', 'SABITRI ROY (BARMAN)', 'SP(WB)', '94']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nGeneral', '889', '832', '10', '1', 'KALIDAS SINGHA', 'SP(WB)', '11'], ['-', '-', '-', '-', '2', 'NAJRUL ALI', 'AITC', '7'], ['-', '-', '-', '-', '3', 'BIPUL CHANDRA SINGHA', 'CPIM', '369'], ['-', '-', '-', '-', '4', 'SURESH BARMAN', 'INC', '435']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '877', '790', '4', '1', 'NEYOTI SARKAR', 'INC', '431'], ['-', '-', '-', '-', '2', 'LAKSHMI DAS', 'SP(WB)', '13'], ['-', '-', '-', '-', '3', 'LALITA BARMAN', 'CPIM', '341'], ['-', '-', '-', '-', '4', 'SHILA BARMAN', 'AITC', '1']], ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('18', '338', '1736')
# Saving file with name 3027. Uttar Dinajpur_RAIGANJ_SERPUR_25-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Selecting GP with key 1737
# Waiting for page and elements to load.....
# Polling date dictionary = OrderedDict([('2013-07-25', '25-07-2013')])
# Selecting date 2013-07-25
# Waiting for page and elements to load.....
# Submitting form data.....
# Waiting for page and elements to load.....
# Fetched data from table = {0: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['I/1\nSCW', '749', '681', '21', '1', 'GAURI DAS', 'INC', '281'], ['-', '-', '-', '-', '2', 'TARA DEBSHARMA', 'SP(WB)', '102'], ['-', '-', '-', '-', '3', 'SHEELA DAS', 'CPIM', '218'], ['-', '-', '-', '-', '4', 'SUMITA DAS', 'AITC', '59']], 1: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['II/2\nSC', '1014', '895', '25', '1', 'DILIP DAS', 'SP(WB)', '128'], ['-', '-', '-', '-', '2', 'RAMEN BARMAN', 'INC', '344'], ['-', '-', '-', '-', '3', 'SHAMBHU NATH BARMAN', 'AITC', '188'], ['-', '-', '-', '-', '4', 'SANJOY BARMAN', 'CPIM', '210']], 2: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['III/3\nW', '1145', '953', '69', '1', 'AKLIMA KHATUN', 'INC', '267'], ['-', '-', '-', '-', '2', 'ABJUNA KHATUN', 'SP(WB)', '196'], ['-', '-', '-', '-', '3', 'AYESHA KHATUN', 'AITC', '338'], ['-', '-', '-', '-', '4', 'HAMEDA KHATUN', 'CPIM', '83']], 3: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IV/4\nSCW', '763', '689', '56', '1', 'TUMPA BARMAN', 'BJP', '102'], ['-', '-', '-', '-', '2', 'BHARATI BARMAN', 'SP(WB)', '143'], ['-', '-', '-', '-', '3', 'MIRA BARMAN', 'INC', '267'], ['-', '-', '-', '-', '4', 'SANDHYA BARMAN (SARKAR)', 'AITC', '121']], 4: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['IX/9\nGeneral', '902', '798', '15', '1', 'AJIJUL RAHAMAN', 'AITC', '135'], ['-', '-', '-', '-', '2', 'ABDUL JABBAR', 'CPIM', '268'], ['-', '-', '-', '-', '3', 'AHA. SARIF', 'SP(WB)', '107'], ['-', '-', '-', '-', '4', 'HOQUE SAHEB MOHAMMAD', 'INC', '273']], 5: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['V/5\nSC', '1044', '871', '28', '1', 'PARESH BARMAN', 'CPIM', '285'], ['-', '-', '-', '-', '2', 'BIJAY BARMAN', 'INC', '138'], ['-', '-', '-', '-', '3', 'BISHAKHA DEBSHARMA', 'AITC', '393'], ['-', '-', '-', '-', '4', 'MAHEN BARMAN', 'SP(WB)', '27']], 6: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VI/6\nSTW', '969', '802', '39', '1', 'PUTUL BESRA', 'AITC', '-'], ['-', '-', '-', '-', '2', 'BASHI HASDA', 'INC', '-'], ['-', '-', '-', '-', '3', 'BHARATI MARDI', 'BJP', '-'], ['-', '-', '-', '-', '4', 'MARSHILA HASDA', 'SP(WB)', '-'], ['-', '-', '-', '-', '5', 'LAKSHMI SAREN', 'CPIM', '-']], 7: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VII/7\nW', '1410', '1273', '9', '1', 'KADBANU BEGAM', 'CPIM', '-'], ['-', '-', '-', '-', '2', 'NURJAHAN BEGHAM', 'IND', '-'], ['-', '-', '-', '-', '3', 'MEHER NEGAR BEGAM', 'INC', '-'], ['-', '-', '-', '-', '4', 'SEFALI KHATUN', 'AITC', '-'], ['-', '-', '-', '-', '5', 'SAKHENA KHATUN', 'SP(WB)', '-']], 8: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['VIII/8\nW', '1096', '961', '31', '1', 'ASHEFA BEGAM', 'SP(WB)', '44'], ['-', '-', '-', '-', '2', 'MASLIMA', 'INC', '378'], ['-', '-', '-', '-', '3', 'REHENA KHATUN', 'AITC', '209'], ['-', '-', '-', '-', '4', 'SABUDA', 'IND', '151'], ['-', '-', '-', '-', '5', 'SALEHA', 'CPIM', '148']], 9: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN', 'Candidate Name', 'Party Name', 'Vote Secured'], ['X/10\nW', '914', '819', '30', '1', 'PAMPA DAS', 'AITC', '11'], ['-', '-', '-', '-', '2', 'PARUL SARKAR', 'INC', '201'], ['-', '-', '-', '-', '3', 'BAJANTI BARMAN', 'SP(WB)', '367'], ['-', '-', '-', '-', '4', 'MILI SARKAR (DAS)', 'CPIM', '210']], 10: [['Seat Name', 'Total Elector', 'Votes Polled', 'Votes Rejected', 'OSN ...
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Formatting Seat Name column for garbage data.....
# Concatenating dataframes.....
# Returning main dataframe.....
# Checkpoint values ('18', '338', '1737')
# Saving file with name 3028. Uttar Dinajpur_RAIGANJ_SITGRAM_25-07-2013.csv to path /content/drive/My Drive/Gram Panchayat Wise
# Ending scraping.....
